# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       4 from sklearn.datasets import make_blobs
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Imports already executed in a previous cell.
# You can use: pd, plt, sns, make_blobs, KMeans, StandardScaler

# %%
# Fix common Matplotlib issues in Jupyter (backend/render state)
# %matplotlib inline

plt.close("all")
plt.rcdefaults()

# Quick check that plotting works
plt.figure()
plt.plot([0, 1, 2], [0, 1, 4], marker="o")
plt.title("Matplotlib test")
plt.show()
